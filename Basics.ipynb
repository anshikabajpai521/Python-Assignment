# %% [markdown]
# QUESTION 1
# What is Python, and why is it popular?
# - Python is high level compiled-interpreted programming language ,it is easy to use and readable ,it has powerfull libraries like NumPy ,Pandas etc and has strong community.

# %% [markdown]
# QUESTION - 2
# What is an interpreter in Python?
# - Interpreter inteprets the code line by line and if any error in the line it does not execute the code further until the correction is  done.

# %% [markdown]
# QUESTION 3
# What are pre-defined keywords in Python?
# - Pre-defined keywords in Python are reserved words that have special meaning .It is dynamic and logical cannnot used as identifiers.For ex- else , if ,str,while ,for ,int ,bool,etc.

# %% [markdown]
# QUESTION 4
# Can keywords be used as variable names?
# -No, keywords cannot be used as variable names .

# %% [markdown]
# QUESTION 5
# What is mutability in Python?
# - Mutable objects can be modified in Python means it can be changed after creation.

# %% [markdown]
# QUESTION 6
# Why are lists mutable, but tuples are immutable?
# -Lists are implemented as dynamic arrays,which allows them to expand ,shrink and overwrite .
# Tuples are implemented as fixed size blocks of memory.

# %% [markdown]
# QUESTION 7
# What is the difference between “==” and “is” operators in Python?
# - "==" is Comparison operator which is used to compare the values or items  and "is" is identity operator which is used to identify the variables refer to the same object .

# %% [markdown]
# QUESTION 8
# What are logical operators in Python?
# -It is used to combine Boolean expressions and also used in conditional statements and in loops .
# for ex-or,and,not

# %% [markdown]
# QUESTION 9
# What is type casting in Python?
# -Type casting is used to convert one data type into another.

# %% [markdown]
# QUESTION 10
# What is the difference between implicit and explicit type casting?
# -There are two types of casting in Python:-
# 1-Explicit:- The programmer manually change the data type by using casting function.Ex-string to integer conversion
# 2-Implicit:- Python automatically caste into  compatible data type.Ex- sum=5+2.0

# %% [markdown]
# QUESTION 11
# What is the purpose of conditional statements in Python?
# -Conditional statements are used to control the flow of execution by giving condition.
# ex-if ,else,elif,continue and break

# %% [markdown]
# QUESTION 12
# How does the elif statement work?
# - When the condition of if statement get false then elif condition will check if it will true then elif statement executes.

# %% [markdown]
# QUESTION 13
# What is the difference between for and while loops?
# -FOR loops are used when number of ierations are given and While loops are used when condtions are given,will continue untill conition fails.

# %% [markdown]
# QUESTION 14
# Describe a scenario where a while loop is more suitable than a for loop?
# -A while loop is more suitable than a for loop when the iterations is not known.

# %% [markdown]
# PRACTICAL QUESTIONS

# %%
"""
QUESTION 1
 Write a Python program to print "Hello, World!"
 """
print("Hello,World!")

# %%
"""
QUESTION 2
Write a Python program that displays your name and age.
"""
print('ANSHIKA-20')

# %%
'''
QUESTION 3
Write code to print all the pre-defined keywords in Python using the keyword library.
'''
import keyword
print(keyword.kwlist)

# %%
'''
QUESTION 4
Write a program that checks if a given word is a Python keyword.
'''
word= input("Enter a word to check:")
if keyword.iskeyword(word):
    print(f"'{words}' is a Python keyword.")
else:
    print(It is NOT a Python keyword)

# %%
'''
QUESTION 5
Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.
'''
my_list= [1,2,3]
hee_tuple= (25,50,75)

print(f"Original list:{my_list}")
print(f"Original tuple:{hee_tuple}")

#Lists are mutuable let's check
my_list[1]=5
print(f"FINAL LIST:{my_list}")

#Tuples are immutable 
hee_tuple(2)==100
except Typeerror as e:
print(f"ERROR:Cannot change element in Tuple!.")

# %%
'''
QUESTION 6
 Write a function to demonstrate the behavior of mutable and immutable arguments.
 '''

def mutability(a_list,a_number):
    a_list.append(100)
    a_number += 50 

    print("List:",a_list)
    print("Number:",a_number)

#outside 

my_list=[1,2,3]
my_number= 10

mutability(my_list,my_number)

#Final output
print("List:",my_list) # list is changed 
print("Number:",my_number) # number remains same
# Out:
# List: [1, 2, 3, 100]
# Number: 60
# List: [1, 2, 3, 100]
# Number: 10

# %%
'''
QUESTION 7
 Write a program that performs basic arithmetic operations on two user-input numbers.
 '''
num1 = int(input("Enter no. 1:"))
num2 = int(input("Enter the  no. 2:"))
product = num1*num2
print(product)

sum = num1+num2
print(sum)
# Out:
# 10
# 7

# %%
'''QUESTION 8
 Write a program to demonstrate the use of logical operators.
 '''
a=10
b=20

#use of AND
if(a>5 and b>12):
    print("it follows AND property")
else:
     print("does not follow" )
# Out:
# it follows AND property

# %%
'''
QUESTION 9
Write a Python program to convert user input from string to integer, float, and boolean types.
'''
# chnge to int
fir= int(input("taking any interger number"))

print(type(fir))

# change to float
flo=float(input("taking flot number"))
print(type(flo))

# change to boolean
baal=bool(input("taking boolean inputs"))
print(type(baal))

# %%
'''
QUESTION 10
Write code to demonstrate type casting with list elements.
'''
prefer=[5,'apple',1.2,{1,2},(2,'aloo')]
print(str(prefer[0]))
print(type(prefer[1]))
print(int(prefer[2]))
print(tuple(prefer[3]))
print(set(prefer[4]))

# %%
'''
QUESTION 11
Write a program that checks if a number is positive, negative, or zero.
'''
num=int(input("taking a number"))
if(num==0):
    print(zero)
elif(num>0):
    print("positive number") 
else:
    print("negative number")

# %%
'''
question 12
 Write a for loop to print numbers from 1 to 10.
 '''
for i in range(1,11):
    print(i)

# %%
'''
QUESTION 13
 Write a Python program to find the sum of all even numbers between 1 and 50.
'''
sum=0
for i in range(1,51):
    if(i%2==0):
        sum=sum+i

print(sum)

# %%
'''
QUESTION 14
Write a program to reverse a string using a while loop.
'''
name='anshika'
rev=""
i=6
while(i>=0):
    rev=rev+name[i]
    i=i-1

print(rev)

# %%
'''QUESTION 15
Write a Python program to calculate the factorial of a number provided by the user using a while loop.
'''
num= int(input("any number"))
i = num
fact=1
while i>=1:
    fact=fact*i
    i=i-1

print(fact)
# Out:
# 6
