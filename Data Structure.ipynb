# %% [markdown]
# '''QUESTION 1 -
# What are data structures, and why are they important?'''

# %% [markdown]
# ANSWER - 1=
# Data structures are the way of organising and storing data items in computer memory so that it can effectively accessible and easy to use.
# Data structures are important for data utilision effectively.It manages memory consumption.

# %% [markdown]
# "QUESTION 2"-Explain the difference between mutable and immutable data types with examples.

# %% [markdown]
# "ANSWER 2"= Mutable Data types are those which can editable after once created .We can add,delete elements in it.
# Immutable data types are those which cannot be edited after once created.We cannot add or dlete items in same existing data type but we performs operation which create new data type.

# %% [markdown]
# "QUESTION 3"-What are the main differences between lists and tuples in Python?

# %% [markdown]
# "ANSWER 3"- Lists are ordered collection of heterogenous data items.Lists are mutable.it is represented by [].
# Tuples are ordred collection of heterogenous data items.tuples are immutable.It is represented by ().

# %% [markdown]
# "QUESTION 4"- Describe how dictionaries store data?

# %% [markdown]
# "ANSWER 4"- Dictionaries store data with key - value pairs.Keys are unique elements and should have stable hash value.Values can store any tpe of data .Dictionaries are mutable .

# %% [markdown]
# "QUESTION 5"- Why might you use a set instead of a list in Python?
#
# "ANSWER 5"- Sets are usually used because it stores unique elements and it does not allow repitation of elements.
# Lists store any data with repitation .

# %% [markdown]
# "QUESTION 6"-What is a string in Python, and how is it different from a list?
#
# "ANSWER 6"-
# String is built-in data type which is a sequence of characters .It stores element under double quotes " ".Strings are immutable.
# Lists are ordered collection and it contains any type of data .Lists are mutable.

# %% [markdown]
# "QUESTION 7"-How do tuples ensure data integrity in Python?
#
# "ANSWER 7"- Tuples ensure data integrity because it is immutable.

# %% [markdown]
# "QUESTION 8"-What is a hash table, and how does it relate to dictionaries in Python?
#
# "ANSWER 8"- A dictionary is a hash table implementation that maps unique ,hashable keys to values , enabling fast lookups.

# %% [markdown]
# "QUESTION 9"-Can lists contain different data types in Python?
#
# "ANSWER 9"- YES,It is a collection of heterogenous data items.

# %% [markdown]
# "QUESTION 10"-"Explain why strings are immutable in Python"?
#
# "ANSWER 10"- To ensure data integrity.

# %% [markdown]
# "QUESTION 11"-What advantages do dictionaries offer over lists for certain task?
#
# "QUESTION 11"-Dictionaries are preferred over lists when data needs to be accessed quickly using unique keys, rather than numeric  indexes.

# %% [markdown]
# "QUESTION 12"-Describe a scenario where using a tuple would be preferable over a list?
#
# "ANSWER 12"-When fixed data list needed where we can not do any change then we use tuples and where we need editing we use lists.

# %% [markdown]
# "QUESTION 13"- How do sets handle duplicate values in Python?
#
# "ANSWER 13"- It automatically removes duplicate items

# %% [markdown]
# "QUESTION 14"-How does the “in” keyword work differently for lists and dictionaries?
#
# "ANSWER 14"- "in" keyword is membership operator which determines the item is present or not in list and in dictionaries it determines key value pairs.

# %% [markdown]
# "QUESTION 15"- Can you modify the elements of a tuple? Explain why or why not?
#
# "ANSWER 15"- NO , we cannot modify the elements of a tuple,because tuple is immutable.

# %% [markdown]
# "QUESTION 16"- What is a nested dictionary, and give an example of its use case?
#
# "ANSWER 16"- It is a way to store  multiple levels of key-value pairs, where a value itself can be another dictionary.
#
# Example:-
#  menu_list={
#
#     "DISH1": {"name":" Pasta","price":12}
#
#     "Dish2":{"name":"maggie","price":16}
# }

# %% [markdown]
# "QUESTION 17"-Describe the time complexity of accessing elements in a dictionary?
#
# "ANSWER 17"-
# Average case-O(1)
# Worst case-O(n)

# %% [markdown]
# "QUESTION 18"-In what situations are lists preferred over dictionaries?
#
# "ANSWER 18"- When the order of elements matters and access the elements with indexes instead of key value pairs .lists contain duplicate values.

# %% [markdown]
# "QUESTION 19"- Why are dictionaries considered unordered, and how does that affect data retrieval?
#
# "ANSWER 19"- They are based on hash tables, not index positions.Items are retrieved by their keys, not by position.
#
# Effect on data retrieval:
# We cannot access dictionary items using an index like dict[0].
# we must use the key to access the value: dict["name"].

# %% [markdown]
# "QUESTION 20"-Explain the difference between a list and a dictionary in terms of data retrieval?
#
# "ANSWER 20"- Lists used for ordered collections accessed by index.Dictionaries used for fast lookups using meaningful keys.

# %% [markdown]
# PRACTICAL QUESTIONS

# %% [markdown]
# QUESTION 1- Write a code to create a string with your name and print it.

# %%
str= "Anshika"
print(str)
# Out:
# Anshika

# %% [markdown]
# QUESTION 2-Write a code to find the length of the string "Hello World".

# %%
str = "HELLO WORLD"
length= len(str)
print(length)
# Out:
# 11

# %% [markdown]
# QUESTION 3-Write a code to slice the first 3 characters from the string "Python Programming".

# %%
str = "PYTHON PROGRAMMING"
slice = str[ :3]
print(slice)
# Out:
# PYT

# %% [markdown]
# QUESTION 4-Write a code to convert the string "hello" to uppercase.

# %%
str="hello"
up = str.upper()
print(up)
# Out:
# HELLO

# %% [markdown]
# QUESTION 5-Write a code to replace the word "apple" with "orange" in the string "I like apple".

# %%
str="I like apple"
new_str =str.replace("apple","orange")
print(new_str)
# Out:
# I like orange

# %% [markdown]
# QUESTION 6-Write a code to create a list with numbers 1 to 5 and print it.

# %%
lis=[1,2,3,4,5]
print(lis)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# QUESTION 7-Write a code to append the number 10 to the list [1, 2, 3, 4].

# %%
lis1=[1,2,3,4]
lis1.append(10)
print(lis1)
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# QUESTION 8-Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].

# %%
list1= [1,2,3,4,5]
list1.pop()
print(list1)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# QUESTION 9-Write a code to access the second element in the list ['a', 'b', 'c', 'd'].

# %%
list1 = ['a','b','c','d']
list1[1]
# Out:
# 'b'

# %% [markdown]
# QUESTION 10-Write a code to reverse the list [10, 20, 30, 40, 50].

# %%
list1= [10,20,30,40,50]
list1.reverse()
print(list1)
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# QUESTION 11-Write a code to create a tuple with the elements 100, 200, 300 and print it.

# %%
tuple1=(100,200,300)
print(tuple1)
# Out:
# (100, 200, 300)

# %% [markdown]
# QUESTION 12-Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

# %%
tuple1 = ("red","green","blue","yellow")
tuple1[1]
# Out:
# 'green'

# %% [markdown]
# QUESTION 13- Write a code to find the minimum number in the tuple (10, 20, 5, 15).

# %%
tuple1=(10,20,5,15)
min_num= min(tuple1)
print(min_num)
# Out:
# 5

# %% [markdown]
# QUESTION 14-Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
Tuple1=("dog","cat","rabbit")
index_bb= Tuple1.index("cat")
print(index_bb)
# Out:
# 1

# %% [markdown]
# QUESTION 15- Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

# %%
tuple1=("apple","mango","kiwi")
"kiwi" in tuple1
# Out:
# True

# %% [markdown]
# QUESTION 16 -Write a code to create a set with the elements 'a', 'b', 'c' and print it.

# %%
set1={'a','b','c'}
print(set1)
# Out:
# {'b', 'a', 'c'}

# %% [markdown]
# QUESTION 17- Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

# %%
set2={1,2,3,4,5}
set2.clear()
print(set2)
# Out:
# set()

# %% [markdown]
# QUESTION 18-Write a code to remove the element 4 from the set {1, 2, 3, 4}.

# %%
he_set={1,2,3,4}
he_set.remove(4)
print(he_set)
# Out:
# {1, 2, 3}

# %% [markdown]
# QUESTION 19- Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

# %%
set1={1,2,3}
set2={3,4,5}
union = set1|set2
print(union)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# QUESTION 20-Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}

# %%
set1={1,2,3}
set2={2,3,4}
intersec= set1&set2
print(intersec)
# Out:
# {2, 3}

# %% [markdown]
# QUESTION 21-Write a code to create a dictionary with the keys "name", "age", and "city", and print it.

# %%
dict1={"name":"Anshika","age":20,"city":"lucknow"}
print(dict1)
# Out:
# {'name': 'Anshika', 'age': 20, 'city': 'lucknow'}

# %% [markdown]
# QUESTION 22- Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.

# %%
dict1={"name":"John","age":25}
dict1["country"]="USA"
print(dict1)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %% [markdown]
# QUESTION 23- Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.

# %%
dict1={"name":"Alice","age":30}
dict1["name"]
# Out:
# 'Alice'

# %% [markdown]
# QUESTION 24- Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.

# %%
dict1={"name":"bob","age":22,"city":"New York"}
dict1.pop("age")
print(dict1)
# Out:
# {'name': 'bob', 'city': 'New York'}

# %% [markdown]
# QUESTION 25-Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.

# %%
dict1={"name":"Alice","city":"Paris"}
if "city" in dict1:
    print("'city'present in dictionary")
else:
    print("'city' is not present in dictionary")
# Out:
# 'city'present in dictionary

# %% [markdown]
# QUESTION 26- Write a code to create a list, a tuple, and a dictionary, and print them all.

# %%
list1=[1,2,3,4]
print(list1)
tuple1=(1,2,3,4)
print(tuple1)
dict1 ={"no.1":1,"no.2":2,"no.3":3,"no.4":4}
print(dict1)
# Out:
# [1, 2, 3, 4]
# (1, 2, 3, 4)
# {'no.1': 1, 'no.2': 2, 'no.3': 3, 'no.4': 4}

# %% [markdown]
# QUESTION 27- Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)

# %%
list1= [51,96,41,78,2]
list1.sort()
print(list1)
# Out:
# [2, 41, 51, 78, 96]

# %% [markdown]
# QUESTION 28- Write a code to create a list with strings and print the element at the third index.

# %%
list1=["apple","banana","grapes","orange","guava"]
new_list=list1[0:3]
print(new_list)
# Out:
# ['apple', 'banana', 'grapes']

# %% [markdown]
# QUESTION 29- Write a code to combine two dictionaries into one and print the result.

# %%
dict1={"name":"abs","age":25}
dict2={"country":"India","contact":2115}
dict3=dict1|dict2
print(dict3)
# Out:
# {'name': 'abs', 'age': 25, 'country': 'India', 'contact': 2115}

# %% [markdown]
# QUESTION 30-Write a code to convert a list of strings into a set

# %%
list1=["red","black","purple","red"]
my_set = set(list1)
print(my_set)
